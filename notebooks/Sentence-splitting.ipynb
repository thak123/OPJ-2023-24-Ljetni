# %% [markdown]
# # Sentence splitting for Croatian non-standard language

# %%
pip install classla
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 16.3 MB/s  0:00:42m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 65.0 MB/s  0:00:04m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.9 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 13.7 MB/s  0:00:01m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 7.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 51.0 MB/s  0:00:07m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 79.0 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 103.2 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 83.0 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 79.2 MB/s  0:00:02m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 86.7 MB/s  0:00:01m0:00:0100:01
# ...

# %%
import classla
classla.download('hr', type='nonstandard')
# Out:
# /home/gthakkar/miniconda3/lib/python3.12/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn(
# ...
# 2026-03-19 11:36:17 INFO: Downloading these customized packages for language: hr (Croatian)...
# ...
# | Processor | Package     |
# ---------------------------
# | tokenize  | nonstandard |
# | pos       | nonstandard |
# | lemma     | nonstandard |
# | depparse  | standard    |
# | ner       | nonstandard |
# | pretrain  | standard    |
# ...
#
# ...
# 2026-03-19 11:36:30 INFO: Finished downloading models and saved to /home/gthakkar/classla_resources.

# %%
nlp = classla.Pipeline('hr', type='nonstandard')  # initialize the default non-standard Slovenian pipeline, use hr for Croatian and sr for Serbian
doc = nlp("Dr. Tomica Bagatin je veliki profesionalac i stručnjak, a još veći čovjek.. Oduševljen sam sa pristupom konzultacijama i samim zahvatom, za preporučiti svima.")     # run the pipeline
print(doc.to_conll())
# Out:
# 2026-03-19 11:37:31 INFO: Loading these models for language: hr (Croatian):
# ...
# | Processor | Package     |
# ---------------------------
# | tokenize  | nonstandard |
# | pos       | nonstandard |
# | lemma     | nonstandard |
# | depparse  | standard    |
# | ner       | nonstandard |
# ...
#
# 2026-03-19 11:37:31 INFO: Use device: gpu
# 2026-03-19 11:37:31 INFO: Loading: tokenize
# 2026-03-19 11:37:31 INFO: Loading: pos
# /home/gthakkar/miniconda3/lib/python3.12/site-packages/torch/cuda/__init__.py:734: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2026-03-19 11:37:34 INFO: Loading: lemma
# 2026-03-19 11:37:43 INFO: Loading: depparse
# 2026-03-19 11:37:45 INFO: Loading: ner
# 2026-03-19 11:37:45 INFO: Done loading processors!
# # newpar id = 1
# # sent_id = 1.1
# # text = Dr. Tomica Bagatin je veliki profesionalac i stručnjak, a još veći čovjek..
# 1	Dr.	dr.	NOUN	Y	_	6	nsubj	_	NER=O
# ...

# %%
text  = "Sve pohvale dr.Dušanki za beskrajnu ljubaznost i ogromnu brigu za pacijente.Već par godina sam njezina pacijentica i mogu samo reći svaka čast.Šunjić Desa"
doc = nlp(text)
print(doc.to_conll())
# Out:
# # newpar id = 1
# # sent_id = 1.1
# # text = Sve pohvale dr.Dušanki za beskrajnu ljubaznost i ogromnu brigu za pacijente.
# 1	Sve	sav	ADJ	Agpfpny	Case=Nom|Definite=Def|Degree=Pos|Gender=Fem|Number=Plur	2	amod	_	NER=O
# 2	pohvale	pohvala	NOUN	Ncfpn	Case=Nom|Gender=Fem|Number=Plur	0	root	_	NER=O
# 3	dr.	dr.	NOUN	Y	_	2	flat	_	NER=O|SpaceAfter=No
# 4	Dušanki	Dušanka	PROPN	Npfsd	Case=Nom|Gender=Fem|Number=Sing	3	flat	_	NER=B-PER
# 5	za	za	ADP	Sa	Case=Acc	7	case	_	NER=O
# 6	beskrajnu	beskrajan	ADJ	Agpfsay	Case=Acc|Definite=Def|Degree=Pos|Gender=Fem|Number=Sing	7	amod	_	NER=O
# 7	ljubaznost	ljubaznost	NOUN	Ncfsa	Case=Acc|Gender=Fem|Number=Sing	2	nmod	_	NER=O
# 8	i	i	CCONJ	Cc	_	10	cc	_	NER=O
# 9	ogromnu	ogroman	ADJ	Agpfsay	Case=Acc|Definite=Def|Degree=Pos|Gender=Fem|Number=Sing	10	amod	_	NER=O
# 10	brigu	briga	NOUN	Ncfsa	Case=Acc|Gender=Fem|Number=Sing	7	conj	_	NER=O
# 11	za	za	ADP	Sa	Case=Acc	12	case	_	NER=O
# ...

# %%
text = "..kod liječnice Pulanić sam od 2011.godine..pregledi su bezbolni ..sestra je simpatična i draga, uvijek se javi na telefon..liječnica nije pričljiva,pa vjerojatno zato loše recenzije,koje nemaju smisla.. dodjem na pregled,a ne na kavu i razgovor..nismo frendice... uvijek mi je dala sve potrebne informacije i uputnice,čak i savjet putem telefona,na što nije obavezna.... mislim da su recenzije subjektivne,nemamo svi isti prag boli niti ista očekivanja... pacijentice znaju postavljati toliko glupa pitanja da je meni u čekaonici neugodno....neke žene bi trebale smanjiti doživljaj i u današnje vrijeme biti upućenije u neke osnovne stvari.."
doc = nlp(text)
print(doc.to_conll())
# Out:
# # newpar id = 1
# # sent_id = 1.1
# # text = ..
# 1	..	..	PUNCT	Z	_	0	root	_	NER=O|SpaceAfter=No
#
# # sent_id = 1.2
# # text = kod liječnice Pulanić sam od 2011.godine..
# 1	kod	kod	ADP	Sg	Case=Gen	2	case	_	NER=O
# 2	liječnice	liječnica	NOUN	Ncfsg	Case=Gen|Gender=Fem|Number=Sing	7	nmod	_	NER=O
# 3	Pulanić	Pulanić	PROPN	Npmsn	Case=Nom|Gender=Masc|Number=Sing	2	flat	_	NER=B-PER
# 4	sam	biti	AUX	Var1s	Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin	7	cop	_	NER=O
# 5	od	od	ADP	Sg	Case=Gen	7	case	_	NER=O
# 6	2011.	2011.	ADJ	Mdo	NumType=Ord	7	amod	_	NER=O|SpaceAfter=No
# 7	godine	godina	NOUN	Ncfsg	Case=Gen|Gender=Fem|Number=Sing	0	root	_	NER=O|SpaceAfter=No
# 8	..	..	PUNCT	Z	_	7	punct	_	NER=O|SpaceAfter=No
#
# # sent_id = 1.3
# # text = pregledi su bezbolni ..
# 1	pregledi	pregled	NOUN	Ncmpn	Case=Nom|Gender=Masc|Number=Plur	3	nsubj	_	NER=O
# 2	su	biti	AUX	Var3p	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	3	cop	_	NER=O
# ...
